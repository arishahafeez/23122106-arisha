# %% [markdown]
# <a href="https://colab.research.google.com/github/arishahafeez/23122106-arisha/blob/main/Areesha_Lab3ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="GEMINI_API_KEY")


MODEL = "models/gemini-3.6-flash"


def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1. Destination Overview
2. Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3. Places to Visit (specific locations)
4. Food Suggestions (local dishes)
5. Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# ...
# Gemini Travel Agent Started (type 'exit' to stop)
#
# You: HI
#
# Agent:
#  AOA and welcome! As your personal Pakistan Tourism travel agent, I am thrilled to help you plan an unforgettable trip.
#
# Since you are looking for a student-friendly budget travel plan, I have selected **Hunza Valley (Gilgit-Baltistan)**—the ultimate paradise for students offering breathtaking scenery, rich culture, and thrilling adventures without breaking the bank.
#
# Here is your comprehensive travel plan:
#
# ---
#
# ### 1. Destination Overview
# * **Destination:** Hunza Valley, Gilgit-Baltistan
# * **Why Visit:** Surrounded by 7,000m+ mountain peaks (including Rakaposhi and Passu Cones), Hunza is world-famous for its crystal-clear turquoise lakes, 800-year-old historic forts, warm-hearted locals, and extremely safe environment.
# * **Best Time to Visit:** May to October (for pleasant weather and greenery) or October/November (for stunning autumn colors).
# * **Ideal Duration:** 5 to 7 days.
#
# ---
#
# ...

# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="GEMINI_API_KEY")


MODEL = "models/gemini-3.6-flash"


def realstate_agent(user_input):

    prompt = f"""
You are a professional agent of smart Ai Realstate Agent.

Provide a well structured plan for Real State:

1. Overview of the property.
2. House rules and amenities.
3. price.
4. Location and amenities.
5. Money-Saving Tips

Make response detailed but easy for clients.

User request: {user_input}

House Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Ai Realstate agent (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = realstate_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# ...
# Gemini Ai Realstate agent (type 'exit' to stop)
#
# You: hi
#
# Agent:
#  Hello! Welcome to **Smart AI Real Estate Services**. I am your virtual real estate advisor, dedicated to helping you find, evaluate, and secure your ideal property seamlessly.
#
# Since you greeted me with "hi," I have generated a **Sample High-Value Real Estate Presentation** below to show you how I structure property plans.
#
# ---
#
# # 🏡 Real Estate Property Profile: *The Horizon Eco-Smart Residence*
#
# ---
#
# ### 1. Overview of the Property
# *A modern, energy-efficient home designed for comfort, luxury, and sustainable living.*
#
# * **Property Type:** Single-Family Smart Home
# * **Size:** 2,200 sq. ft.
# * **Layout:** 3 Bedrooms | 2.5 Bathrooms | 2-Car Garage
# * **Key Features:**
#   * Open-concept living room with floor-to-ceiling windows for natural sunlight.
#   * Fully equipped chef's kitchen with quartz countertops and stainless-steel appliances.
# ...
